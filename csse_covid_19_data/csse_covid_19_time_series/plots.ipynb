# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
conf = pd.read_csv('US_Confirmed.csv')
dead = pd.read_csv('US_Deaths.csv')

# %%
x=conf['Key']
y=conf['Confirmed Cases']

x1=dead['Key']
y1=dead['Deaths']

# %%
p = np.poly1d(np.polyfit(x, y, 6))
t=np.arange(0,60,.01)
plt.plot(x, y, 'o', t, p(t), '-')

plt.title('US COVID-19 Confirmed Cases')
plt.grid()
plt.savefig('3-18_Confirmed.jpeg', dpi=600)

# %%
p = np.poly1d(np.polyfit(x1, y1, 6))
t=np.arange(0,60,.01)
plt.plot(x1, y1, 'o', t, p(t), '-')

plt.title('US COVID-19 Deaths')
plt.grid()
plt.savefig('3-18_Deaths.jpeg', dpi=600)
