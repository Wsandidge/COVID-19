# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
data = np.genfromtxt('time_series_19-covid-Confirmed.csv', delimiter=',',usecols=np.arange(0,1434), invalid_raise = False)
dta = pd.read_csv('US_Confirmed.csv')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: ConversionWarning: Some errors were detected !
#     Line #1 (got 59 columns instead of 1434)
#     Line #2 (got 59 columns instead of 1434)
#     Line #3 (got 59 columns instead of 1434)
#     Line #4 (got 59 columns instead of 1434)
#     Line #5 (got 59 columns instead of 1434)
#     Line #6 (got 59 columns instead of 1434)
#     Line #7 (got 59 columns instead of 1434)
#     Line #8 (got 59 columns instead of 1434)
#     Line #9 (got 59 columns instead of 1434)
#     Line #10 (got 59 columns instead of 1434)
#     Line #11 (got 59 columns instead of 1434)
#     Line #12 (got 59 columns instead of 1434)
#     Line #13 (got 59 columns instead of 1434)
#     Line #14 (got 59 columns instead of 1434)
#     Line #15 (got 59 columns instead of 1434)
#     Line #16 (got 59 columns instead of 1434)
#     Line #17 (got 59 columns instead of 1434)
#     Line #18 (got 59 columns instead of 1434)
# ...

# %%
headers = ['Province/State','Country/Region','1/22/2020']
dta['Date']
# Out:
# 0     1/22/2020
# 1     1/23/2020
# 2     1/24/2020
# 3     1/25/2020
# 4     1/26/2020
# 5     1/27/2020
# 6     1/28/2020
# 7     1/29/2020
# 8     1/30/2020
# 9     1/31/2020
# 10     2/1/2020
# 11     2/2/2020
# 12     2/3/2020
# 13     2/4/2020
# 14     2/5/2020
# 15     2/6/2020
# 16     2/7/2020
# 17     2/8/2020
# 18     2/9/2020
# 19    2/10/2020
# 20    2/11/2020
# 21    2/12/2020
# 22    2/13/2020
# 23    2/14/2020
# 24    2/15/2020
# 25    2/16/2020
# 26    2/17/2020
# 27    2/18/2020
# 28    2/19/2020
# 29    2/20/2020
# 30    2/21/2020
# 31    2/22/2020
# 32    2/23/2020
# 33    2/24/2020
# 34    2/25/2020
# 35    2/26/2020
# 36    2/27/2020
# 37    2/28/2020
# 38    2/29/2020
# 39     3/1/2020
# 40     3/2/2020
# 41     3/3/2020
# 42     3/4/2020
# 43     3/5/2020
# 44     3/6/2020
# 45     3/7/2020
# 46     3/8/2020
# 47     3/9/2020
# 48    3/10/2020
# 49    3/11/2020
# 50    3/12/2020
# 51    3/13/2020
# 52    3/14/2020
# 53    3/15/2020
# 54    3/16/2020
# ...

# %%
x=dta['Key']
y=dta['Confirmed Cases']

z=np.polyfit(x,y,6)

plt.plot(x,y)
z
# Out:
# array([ 1.19816680e-05, -1.72243730e-03,  9.45593375e-02, -2.45550817e+00,
#         3.02486595e+01, -1.52992383e+02,  2.09963943e+02])

# %%
p = np.poly1d(np.polyfit(x, y, 6))
plt.plot(x, y, 'o', x, p(x), '-')
